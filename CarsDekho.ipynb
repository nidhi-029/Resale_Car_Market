# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhi-029/Resale_Car_Market/blob/main/CarsDekho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
def process_city_data(city_df):
    rows = []

    for i in range(city_df.shape[0]):
        data_dict  = ast.literal_eval(city_df['new_car_detail'][i])
        data_dict1 = ast.literal_eval(city_df['new_car_overview'][i])
        data_dict2 = ast.literal_eval(city_df['new_car_specs'][i])

        try:
            if data_dict2['data'][0]['list'][2]['value'].isnumeric():
                eng_cc = data_dict2['data'][0]['list'][2]['value']
            else:
                eng_cc = data_dict2['data'][0]['list'][1]['value']
        except:
            eng_cc = np.nan

        row = {
            "Fuel_Type": data_dict['ft'],
            "Kilometers_Driven": data_dict['km'],
            "Transmission_Type": data_dict['transmission'],
            "No_of_Owners": data_dict['ownerNo'],
            "Manufactured_By": data_dict['oem'],
            "Car_Model": data_dict['model'],
            "Car_Produced_Year": int(data_dict['modelYear']),
            "Car_Price": float(data_dict['price'][2:-5]) * 100000,
            "Registration_Year": data_dict1['top'][0]['value'][-4:],
            "No_of_Seats": data_dict1['top'][3]['value'][0],
            "Engine_CC": eng_cc,
            "Mileage(kmpl)": data_dict2['top'][0]['value'][:-5]
        }
        rows.append(row)

    # merge back into the dataframe
    return pd.concat([city_df, pd.DataFrame(rows)], axis=1)

# %% [markdown]
# **Banglore Dataset**

# %%
banglore_data = pd.read_excel("bangalore_cars.xlsx")
banglore_data = process_city_data(banglore_data)
banglore_data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links Fuel_Type  \
# 0  https://www.cardekho.com/used-car-details/used...    Petrol
# 1  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 2  https://www.cardekho.com/used-car-details/used...    Petrol
# 3  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 4  https://www.cardekho.com/used-car-details/used...    Diesel
#
#   Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0          1,20,000            Manual             3          Maruti
# 1            32,706            Manual             2            Ford
# 2            11,949            Manual             1            Tata
# 3            17,794            Manual             1         Hyundai
# 4            60,000            Manual             1          Maruti
#
#             Car_Model  Car_Produced_Year  Car_Price Registration_Year  \
# 0      Maruti Celerio               2015   400000.0              2015
# 1       Ford Ecosport               2018   811000.0              2018
# 2          Tata Tiago               2018   585000.0              2018
# 3       Hyundai Xcent               2014   462000.0              2014
# 4  Maruti SX4 S Cross               2015   790000.0              2015
#
#   No_of_Seats Engine_CC Mileage(kmpl)
# 0           5       998          23.1
# 1           5      1497            17
# 2           5      1199         23.84
# 3           5      1197          19.1
# 4           5      1248         23.65

# %%
banglore_data['Location'] = 'Banglore'

# %% [markdown]
# **Chennai Dataset**

# %%
chennai_data = pd.read_excel("/content/chennai_cars.xlsx")
chennai_data = process_city_data(chennai_data)
chennai_data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Low...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs Fuel_Type  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...    Petrol
# 1  {'heading': 'Specifications', 'top': [{'key': ...    Petrol
# 2  {'heading': 'Specifications', 'top': [{'key': ...    Petrol
# 3  {'heading': 'Specifications', 'top': [{'key': ...    Petrol
# 4  {'heading': 'Specifications', 'top': [{'key': ...    Petrol
#
#   Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0            20,000         Automatic             1             Kia
# 1            20,687            Manual             1          Maruti
# 2            30,000            Manual             1          Nissan
# 3            59,247            Manual             1         Hyundai
# 4            50,000            Manual             1           Honda
#
#         Car_Model  Car_Produced_Year  Car_Price Registration_Year No_of_Seats  \
# 0       Kia Sonet               2022  1150000.0              2022           5
# 1     Maruti Eeco               2015   415000.0              2015           7
# 2  Nissan Magnite               2021   750000.0              2021           5
# 3     Hyundai i10               2015   398000.0              2015           5
# 4      Honda Jazz               2015   550000.0              2015           5
#
#   Engine_CC Mileage(kmpl)
# 0       998             9
# 1      1196         15.37
# 2       999            20
# 3      1086         19.81
# 4      1199          18.7

# %%
chennai_data['Location'] = 'Chennai'

# %% [markdown]
# **Kolkata Dataset**

# %%
kolkata_data = pd.read_excel("/content/kolkata_cars.xlsx")
kolkata_data = process_city_data(kolkata_data)
kolkata_data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links Fuel_Type  \
# 0  https://www.cardekho.com/used-car-details/used...    Petrol
# 1  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 2  https://www.cardekho.com/used-car-details/used...    Petrol
# 3  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 4  https://www.cardekho.com/used-car-details/used...    Diesel
#
#   Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0            70,000         Automatic             3          Toyota
# 1            23,981            Manual             1          Datsun
# 2             7,100         Automatic             1         Renault
# 3            71,574            Manual             2         Hyundai
# 4            50,000         Automatic             2            Audi
#
#        Car_Model  Car_Produced_Year  Car_Price Registration_Year No_of_Seats  \
# 0   Toyota Camry               2014   975000.0              2014           5
# 1  Datsun RediGO               2017   266000.0              2017           5
# 2  Renault Kiger               2021   595000.0              2021           5
# 3    Hyundai i20               2011   223000.0              2012           5
# 4        Audi Q3               2014  1200000.0              2014           5
#
#   Engine_CC Mileage(kmpl)
# 0      2494         19.16
# 1       799          22.7
# 2       999         19.03
# 3      1197            17
# 4      1968         15.73

# %%
kolkata_data['Location'] = "Kolkata"

# %% [markdown]
# **Jaipur Dataset**

# %%
jaipur_data = pd.read_excel("/content/jaipur_cars.xlsx")
jaipur_data = process_city_data(jaipur_data)
jaipur_data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links Fuel_Type  \
# 0  https://www.cardekho.com/used-car-details/used...    Diesel
# 1  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 2  https://www.cardekho.com/used-car-details/used...    Petrol
# 3  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 4  https://www.cardekho.com/used-car-details/used...    Petrol
#
#   Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0          1,20,000            Manual             2         Hyundai
# 1            66,951            Manual             1          Maruti
# 2            80,000         Automatic             2          Maruti
# 3            44,392            Manual             1         Hyundai
# 4            40,000         Automatic             1          Maruti
#
#            Car_Model  Car_Produced_Year  Car_Price Registration_Year  \
# 0        Hyundai i20               2015   510000.0              2015
# 1       Maruti Swift               2012   381000.0              2012
# 2     Maruti Celerio               2016   320000.0              2016
# 3  Hyundai Grand i10               2017   420000.0              2017
# 4     Maruti Wagon R               2016   350000.0              2016
#
#   No_of_Seats Engine_CC Mileage(kmpl)
# 0           5      1396         22.54
# 1           5      1197         22.38
# 2           5       998          23.1
# 3           5      1197          18.9
# 4           5       998         20.51

# %%
jaipur_data['Location'] = 'Jaipur'

# %% [markdown]
# **Delhi Dataset**

# %%
delhi_data = pd.read_excel("/content/delhi_cars.xlsx")
delhi_data = process_city_data(delhi_data)
delhi_data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links Fuel_Type  \
# 0  https://www.cardekho.com/used-car-details/used...    Diesel
# 1  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 2  https://www.cardekho.com/used-car-details/used...    Petrol
# 3  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 4  https://www.cardekho.com/used-car-details/used...    Petrol
#
#   Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0            10,000         Automatic             1             Kia
# 1            57,437            Manual             2         Hyundai
# 2             8,000         Automatic             1   Mercedes-Benz
# 3            28,151            Manual             2          Maruti
# 4            60,000            Manual             1         Hyundai
#
#            Car_Model  Car_Produced_Year  Car_Price Registration_Year  \
# 0         Kia Seltos               2022  1900000.0              2022
# 1      Hyundai Creta               2016   762000.0              2016
# 2  Mercedes-Benz GLC               2020  5600000.0              2020
# 3       Maruti Swift               2018   523000.0              2019
# 4      Hyundai Creta               2017   765000.0              2017
#
#   No_of_Seats Engine_CC Mileage(kmpl)
# 0           5      1493            18
# 1           5      1591         15.29
# 2           5      1991         12.74
# 3           5      1197         22.38
# 4           5      1591         15.29

# %%
delhi_data['Location'] = 'Delhi'

# %% [markdown]
# **Hyderabad Dataset**

# %%
hyd_data = pd.read_excel("/content/hyderabad_cars.xlsx")
hyd_data = process_city_data(hyd_data)
hyd_data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links Fuel_Type  \
# 0  https://www.cardekho.com/used-car-details/used...    Petrol
# 1  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 2  https://www.cardekho.com/used-car-details/used...    Petrol
# 3  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 4  https://www.cardekho.com/used-car-details/used...    Petrol
#
#   Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0            20,000         Automatic             1      Volkswagen
# 1            85,582            Manual             2         Hyundai
# 2            10,000            Manual             1         Hyundai
# 3            50,750            Manual             1          Maruti
# 4            10,000         Automatic             1        Mahindra
#
#          Car_Model  Car_Produced_Year  Car_Price Registration_Year  \
# 0  Volkswagen Polo               2022  1044000.0              2022
# 1      Hyundai EON               2014   260000.0              2014
# 2    Hyundai Venue               2023   955000.0              2023
# 3    Maruti Baleno               2017   671000.0              2017
# 4    Mahindra Thar               2022  1900000.0              2022
#
#   No_of_Seats Engine_CC Mileage(kmpl)
# 0           5       999         16.47
# 1           5       814          21.1
# 2           5      1197            11
# 3           5      1197          21.4
# 4           4      1997            19

# %%
hyd_data['Location'] = 'Hyderabad'

# %% [markdown]
# **Concatenating the different Locations**

# %%
data = pd.concat([banglore_data, chennai_data, kolkata_data, jaipur_data, delhi_data, hyd_data]).reset_index()

# %%
data.shape
# Out:
# (8369, 19)

# %%
data.head(20)
# Out:
#     index                                     new_car_detail  \
# 0       0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1       1  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2       2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3       3  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4       4  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 5       5  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 6       6  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 7       7  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 8       8  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 9       9  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 10     10  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 11     11  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 12     12  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 13     13  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 14     14  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 15     15  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 16     16  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 17     17  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 18     18  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 19     19  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
#
#                                      new_car_overview  \
# 0   {'heading': 'Car overview', 'top': [{'key': 'R...
# 1   {'heading': 'Car overview', 'top': [{'key': 'R...
# 2   {'heading': 'Car overview', 'top': [{'key': 'R...
# 3   {'heading': 'Car overview', 'top': [{'key': 'R...
# 4   {'heading': 'Car overview', 'top': [{'key': 'R...
# 5   {'heading': 'Car overview', 'top': [{'key': 'R...
# 6   {'heading': 'Car overview', 'top': [{'key': 'R...
# 7   {'heading': 'Car overview', 'top': [{'key': 'R...
# 8   {'heading': 'Car overview', 'top': [{'key': 'R...
# 9   {'heading': 'Car overview', 'top': [{'key': 'R...
# 10  {'heading': 'Car overview', 'top': [{'key': 'R...
# 11  {'heading': 'Car overview', 'top': [{'key': 'R...
# 12  {'heading': 'Car overview', 'top': [{'key': 'R...
# 13  {'heading': 'Car overview', 'top': [{'key': 'R...
# 14  {'heading': 'Car overview', 'top': [{'key': 'R...
# 15  {'heading': 'Car overview', 'top': [{'key': 'R...
# 16  {'heading': 'Car overview', 'top': [{'key': 'R...
# 17  {'heading': 'Car overview', 'top': [{'key': 'R...
# 18  {'heading': 'Car overview', 'top': [{'key': 'R...
# 19  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                       new_car_feature  \
# 0   {'heading': 'Features', 'top': [{'value': 'Pow...
# 1   {'heading': 'Features', 'top': [{'value': 'Pow...
# 2   {'heading': 'Features', 'top': [{'value': 'Pow...
# 3   {'heading': 'Features', 'top': [{'value': 'Pow...
# 4   {'heading': 'Features', 'top': [{'value': 'Pow...
# 5   {'heading': 'Features', 'top': [{'value': 'Pow...
# 6   {'heading': 'Features', 'top': [{'value': 'Pow...
# 7   {'heading': 'Features', 'top': [{'value': 'Pow...
# 8   {'heading': 'Features', 'top': [{'value': 'Pow...
# 9   {'heading': 'Features', 'top': [{'value': 'Pow...
# 10  {'heading': 'Features', 'top': [{'value': 'Pow...
# 11  {'heading': 'Features', 'top': [{'value': 'Pow...
# 12  {'heading': 'Features', 'top': [{'value': 'Pow...
# 13  {'heading': 'Features', 'top': [{'value': 'Pow...
# 14  {'heading': 'Features', 'top': [{'value': 'Pow...
# 15  {'heading': 'Features', 'top': [{'value': 'Pow...
# 16  {'heading': 'Features', 'top': [{'value': 'Pow...
# 17  {'heading': 'Features', 'top': [{'value': 'Pow...
# 18  {'heading': 'Features', 'top': [{'value': 'Pow...
# 19  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                         new_car_specs  \
# 0   {'heading': 'Specifications', 'top': [{'key': ...
# 1   {'heading': 'Specifications', 'top': [{'key': ...
# 2   {'heading': 'Specifications', 'top': [{'key': ...
# 3   {'heading': 'Specifications', 'top': [{'key': ...
# 4   {'heading': 'Specifications', 'top': [{'key': ...
# 5   {'heading': 'Specifications', 'top': [{'key': ...
# 6   {'heading': 'Specifications', 'top': [{'key': ...
# 7   {'heading': 'Specifications', 'top': [{'key': ...
# 8   {'heading': 'Specifications', 'top': [{'key': ...
# 9   {'heading': 'Specifications', 'top': [{'key': ...
# 10  {'heading': 'Specifications', 'top': [{'key': ...
# 11  {'heading': 'Specifications', 'top': [{'key': ...
# 12  {'heading': 'Specifications', 'top': [{'key': ...
# 13  {'heading': 'Specifications', 'top': [{'key': ...
# 14  {'heading': 'Specifications', 'top': [{'key': ...
# 15  {'heading': 'Specifications', 'top': [{'key': ...
# 16  {'heading': 'Specifications', 'top': [{'key': ...
# 17  {'heading': 'Specifications', 'top': [{'key': ...
# 18  {'heading': 'Specifications', 'top': [{'key': ...
# 19  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                             car_links Fuel_Type  \
# 0   https://www.cardekho.com/used-car-details/used...    Petrol
# 1   https://www.cardekho.com/buy-used-car-details/...    Petrol
# 2   https://www.cardekho.com/used-car-details/used...    Petrol
# 3   https://www.cardekho.com/buy-used-car-details/...    Petrol
# 4   https://www.cardekho.com/used-car-details/used...    Diesel
# 5   https://www.cardekho.com/used-car-details/used...    Diesel
# 6   https://www.cardekho.com/buy-used-car-details/...    Petrol
# 7   https://www.cardekho.com/used-car-details/used...    Petrol
# 8   https://www.cardekho.com/used-car-details/used...    Petrol
# 9   https://www.cardekho.com/buy-used-car-details/...    Petrol
# 10  https://www.cardekho.com/used-car-details/used...    Petrol
# 11  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 12  https://www.cardekho.com/used-car-details/used...    Petrol
# 13  https://www.cardekho.com/buy-used-car-details/...    Petrol
# 14  https://www.cardekho.com/buy-used-car-details/...    Diesel
# 15  https://www.cardekho.com/used-car-details/used...    Diesel
# 16  https://www.cardekho.com/used-car-details/used...    Diesel
# 17  https://www.cardekho.com/buy-used-car-details/...    Diesel
# 18  https://www.cardekho.com/used-car-details/used...    Petrol
# 19  https://www.cardekho.com/used-car-details/used...    Petrol
#
#    Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0           1,20,000            Manual             3          Maruti
# 1             32,706            Manual             2            Ford
# 2             11,949            Manual             1            Tata
# 3             17,794            Manual             1         Hyundai
# 4             60,000            Manual             1          Maruti
# 5             20,000            Manual             1            Jeep
# 6             37,772            Manual             1          Datsun
# 7             30,000         Automatic             1         Hyundai
# 8             37,000         Automatic             1          Maruti
# 9             11,949            Manual             1            Tata
# 10            50,000            Manual             1          Maruti
# 11            24,887         Automatic             1         Hyundai
# 12            23,000         Automatic             1           Honda
# 13            48,928         Automatic             1            Tata
# 14          1,08,862            Manual             3        Mahindra
# 15            80,000            Manual             1            Jeep
# 16            16,000         Automatic             1   Mercedes-Benz
# 17            65,376            Manual             2         Hyundai
# 18            10,000            Manual             1            Tata
# 19            67,000            Manual             2           Honda
#
#              Car_Model  Car_Produced_Year  Car_Price Registration_Year  \
# 0       Maruti Celerio               2015   400000.0              2015
# 1        Ford Ecosport               2018   811000.0              2018
# 2           Tata Tiago               2018   585000.0              2018
# 3        Hyundai Xcent               2014   462000.0              2014
# 4   Maruti SX4 S Cross               2015   790000.0              2015
# 5         Jeep Compass               2020  1900000.0              2020
# 6            Datsun GO               2017   345000.0              2017
# 7        Hyundai Venue               2021  1200000.0              2021
# 8          Maruti Ciaz               2018   960000.0              2018
# 9           Tata Tiago               2017   585000.0              2018
# 10       Maruti Baleno               2018   690000.0              2018
# 11   Hyundai Grand i10               2019   682000.0              2019
# 12          Honda Jazz               2018   825000.0              2018
# 13          Tata Tiago               2018   595000.0              2018
# 14     Mahindra XUV500               2014   690000.0              2014
# 15        Jeep Compass               2018  1350000.0              2018
# 16   Mercedes-Benz GLA               2022  5595000.0              2022
# 17         Hyundai i20               2014   521000.0              2014
# 18          Tata Nexon               2022  1005000.0              2022
# 19          Honda City               2016   775000.0              2016
#
#    No_of_Seats Engine_CC Mileage(kmpl)  Location
# 0            5       998          23.1  Banglore
# 1            5      1497            17  Banglore
# 2            5      1199         23.84  Banglore
# 3            5      1197          19.1  Banglore
# 4            5      1248         23.65  Banglore
# 5            5      1956          17.1  Banglore
# 6            5      1198         20.63  Banglore
# 7            5       998         18.15  Banglore
# 8            5      1462         20.28  Banglore
# 9            5      1199         23.84  Banglore
# 10           5      1197          21.4  Banglore
# 11           5      1197          18.9  Banglore
# 12           5      1199          18.2  Banglore
# 13           5      1199         23.84  Banglore
# 14           7      2179          15.1  Banglore
# 15           5      1956          17.1  Banglore
# 16           5      1950            19  Banglore
# 17           5      1396         21.27  Banglore
# 18           5      1199         17.33  Banglore
# 19           5      1497          17.8  Banglore

# %% [markdown]
# **Drop the unrequired Columns**

# %%
data.drop(['index','new_car_detail','new_car_overview','new_car_feature','new_car_specs','car_links'], axis = 1, inplace = True)

# %%
Car_Produced_Year = data[data['Registration_Year'].isin(['sive', 'able', 'ance','arty'])]['Car_Produced_Year']
data.loc[data['Registration_Year'].isin(['sive', 'able', 'ance','arty']),'Registration_Year'] = Car_Produced_Year

# %%
data['Car_Age'] = data['Car_Produced_Year'].apply(lambda x: 2025-x)

# %%
print(data.shape)
data.head()
# Out:
# (8369, 14)
#   Fuel_Type Kilometers_Driven Transmission_Type  No_of_Owners Manufactured_By  \
# 0    Petrol          1,20,000            Manual             3          Maruti
# 1    Petrol            32,706            Manual             2            Ford
# 2    Petrol            11,949            Manual             1            Tata
# 3    Petrol            17,794            Manual             1         Hyundai
# 4    Diesel            60,000            Manual             1          Maruti
#
#             Car_Model  Car_Produced_Year  Car_Price Registration_Year  \
# 0      Maruti Celerio               2015   400000.0              2015
# 1       Ford Ecosport               2018   811000.0              2018
# 2          Tata Tiago               2018   585000.0              2018
# 3       Hyundai Xcent               2014   462000.0              2014
# 4  Maruti SX4 S Cross               2015   790000.0              2015
#
#   No_of_Seats Engine_CC Mileage(kmpl)  Location  Car_Age
# 0           5       998          23.1  Banglore       10
# 1           5      1497            17  Banglore        7
# 2           5      1199         23.84  Banglore        7
# 3           5      1197          19.1  Banglore       11
# 4           5      1248         23.65  Banglore       10

# %% [markdown]
# **Checking the unique engine_cc values**

# %%
data['Engine_CC'].unique()
# Out:
# array(['998', '1497', '1199', '1197', '1248', '1956', '1198', '1462',
#        '2179', '1950', '1396', '1995', '1498', '4663', '1086', '1991',
#        '1968', '1998', '2982', '1461', '1797', '796', '1353', '2925',
#        '2987', '2967', '999', '1341', '1496', '1582', '1798', '1120',
#        '1969', '1451', '814', '1999', '1591', '1397', '1368', '1598',
#        '3198', '1196', '2993', '2755', '2143', '2354', '1332', '2199',
#        '1997', '1499', '2148', '2696', '1364', '2494', '1373', '1299',
#        '1061', '1493', '2497', '1495', '1590', '1896', '1330', '1781',
#        '1390', '1194', '2953', '1399', '1595', 'Power', '2496',
#        '210AH Lithium Ion', '0', '1984', nan, '2694', '1298', '2362',
#        '2198', '1599', '993', '2393', '1389', '1597', '2498', '2523',
#        '1586', '995', '2499', '2998', '72', '1589', '624', '1596', '799',
#        '3597', '2184', '1405', '5000', '1422', '1047', '2200', '2996',
#        '1108', '2400', '1996', '1395', '1186', '1799', '2999', '1482',
#        '793', '936', '4134', '1796', '1172', '1468', '1193', '2477',
#        '2997', '2995', '2487', '1817', '3993', '1948', '4806', '2359',
#        '3982', '2157', '1794', '2994', '1993', '1490', '1349', '2609',
#        '3498', '2489', '2835', '1150', '1343', '2981', '4395', '3456',
#        '2360', '2894', '3346', '2979', '1985', '2956', '2231', '2446'],
#       dtype=object)

# %%
data.loc[(data['Engine_CC'].isin(['210AH Lithium Ion','Power','72','0']))|(data['Engine_CC'].isna()==True)]['Engine_CC'].value_counts()
# Out:
# Engine_CC
# 0                    26
# Power                 3
# 210AH Lithium Ion     1
# 72                    1
# Name: count, dtype: int64

# %%
data.loc[data['Engine_CC'].isin(['72']),'Engine_CC'] = '720'
engine_cc = data.loc[data['Engine_CC'].isin(['Power','210AH Lithium Ion'])]
data.drop(engine_cc.index, inplace = True)

# %%
empty_values = data.loc[data['Mileage(kmpl)']=='']
data.drop(empty_values.index, inplace = True)

# %% [markdown]
# **Checking the model and company to match with the existing engine_cc**

# %%
data.loc[(data['Engine_CC'].isin(['0']))|(data['Engine_CC'].isna()==True)][['Manufactured_By','Car_Model']]
# Out:
#        Manufactured_By                      Car_Model
# 600            Hyundai            Hyundai Santro Xing
# 637            Hyundai                 Hyundai Santro
# 690             Maruti                    Maruti 1000
# 747            Hyundai            Hyundai Santro Xing
# 902             Maruti                  Maruti Esteem
# 976            Hyundai            Hyundai Santro Xing
# 984             Maruti                   Maruti Swift
# 1014           Hyundai            Hyundai Santro Xing
# 1016            Maruti                    Maruti Omni
# 1055              Ford                    Ford Mondeo
# 1065           Hyundai            Hyundai Santro Xing
# 1175            Maruti                  Maruti Estilo
# 1195            Maruti                   Maruti Swift
# 1276           Hyundai                 Hyundai Tucson
# 1759           Hyundai                 Hyundai Santro
# 1991              Tata                    Tata Indica
# 2006              Ford                    Ford Fiesta
# 2195              Ford                    Ford Mondeo
# 2340              Ford                    Ford Fiesta
# 2462            Toyota              Toyota Etios Liva
# 2494           Hyundai            Hyundai Santro Xing
# 2536           Hyundai            Hyundai Santro Xing
# 2616           Hyundai            Hyundai Santro Xing
# 2617           Hyundai            Hyundai Santro Xing
# 2651           Hyundai            Hyundai Santro Xing
# 3157           Hyundai            Hyundai Santro Xing
# 3161            Toyota              Toyota Etios Liva
# 3465            Toyota              Toyota Etios Liva
# 3467             Honda                     Honda CR-V
# 3520            Maruti                  Maruti Estilo
# 3581            Maruti                  Maruti Estilo
# 3844            Toyota              Toyota Etios Liva
# 3853              Ford                    Ford Fiesta
# 4013             Honda                     Honda CR-V
# 4172              Ford                    Ford Fiesta
# 4462              Tata                    Tata Indica
# 4520           Hyundai            Hyundai Santro Xing
# 4624              Ford                 Ford Endeavour
# 4700           Hyundai                 Hyundai Santro
# 4921           Hyundai                 Hyundai Santro
# 4969            Maruti                  Maruti Esteem
# 5036           Hyundai            Hyundai Santro Xing
# 5054           Hyundai            Hyundai Santro Xing
# 5246              Tata                    Tata Indica
# 5785            Toyota                   Toyota Etios
# 6254           Hyundai            Hyundai Santro Xing
# 6726            Maruti  Maruti Celerio Tour 2018-2021
# 7055          Mahindra                  Mahindra Jeep
# 7095            Toyota                  Toyota Qualis
# 7639            Toyota                   Toyota Etios
# 7663              Tata                    Tata Indica
# 7951           Hyundai            Hyundai Santro Xing
# 7974           Hyundai                 Hyundai Santro
# 8045  Hindustan Motors      Hindustan Motors Contessa
# 8068           Hyundai            Hyundai Santro Xing
# 8090              Ford                    Ford Fiesta
# 8139           Hyundai            Hyundai Santro Xing

# %%
mask = (data['Engine_CC'].isin(['0'])) | (data['Engine_CC'].isna())

for i, j in zip(data.loc[mask, 'Manufactured_By'], data.loc[mask, 'Car_Model']):
    value = data.loc[(data['Manufactured_By'] == i) & (data['Car_Model'] == j), 'Engine_CC'].value_counts().index[0]
    data.loc[mask, 'Engine_CC'] = value

# %%
data.loc[(data['Engine_CC'].isin(['0']))|(data['Engine_CC'].isna()==True)].shape
# Out:
# (0, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8339 entries, 0 to 8368
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fuel_Type          8339 non-null   object
#  1   Kilometers_Driven  8339 non-null   object
#  2   Transmission_Type  8339 non-null   object
#  3   No_of_Owners       8339 non-null   int64
#  4   Manufactured_By    8339 non-null   object
#  5   Car_Model          8339 non-null   object
#  6   Car_Produced_Year  8339 non-null   int64
#  7   Car_Price          8339 non-null   float64
#  8   Registration_Year  8339 non-null   object
#  9   No_of_Seats        8339 non-null   object
#  10  Engine_CC          8339 non-null   object
#  11  Mileage(kmpl)      8339 non-null   object
#  12  Location           8339 non-null   object
#  13  Car_Age            8339 non-null   int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 977.2+ KB

# %%
data['Kilometers_Driven'] = pd.to_numeric(data['Kilometers_Driven'].str.replace(',',''))
data['Registration_Year'] = pd.to_numeric(data['Registration_Year'])
data['No_of_Seats'] = pd.to_numeric(data['No_of_Seats'])
data['Engine_CC'] = pd.to_numeric(data['Engine_CC'])
data['Mileage(kmpl)'] = pd.to_numeric(data['Mileage(kmpl)'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8339 entries, 0 to 8368
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fuel_Type          8339 non-null   object
#  1   Kilometers_Driven  8339 non-null   int64
#  2   Transmission_Type  8339 non-null   object
#  3   No_of_Owners       8339 non-null   int64
#  4   Manufactured_By    8339 non-null   object
#  5   Car_Model          8339 non-null   object
#  6   Car_Produced_Year  8339 non-null   int64
#  7   Car_Price          8339 non-null   float64
#  8   Registration_Year  8339 non-null   int64
#  9   No_of_Seats        8339 non-null   int64
#  10  Engine_CC          8339 non-null   int64
#  11  Mileage(kmpl)      8339 non-null   float64
#  12  Location           8339 non-null   object
#  13  Car_Age            8339 non-null   int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 977.2+ KB

# %%
data[data.duplicated()]
# Out:
#      Fuel_Type  Kilometers_Driven Transmission_Type  No_of_Owners  \
# 79      Petrol              60000            Manual             2
# 114     Petrol              20000         Automatic             1
# 124     Petrol              80000            Manual             3
# 183     Petrol             120000            Manual             3
# 197     Petrol              50000            Manual             1
# ...        ...                ...               ...           ...
# 8279    Petrol              80000            Manual             2
# 8325    Petrol              80000            Manual             2
# 8336    Diesel              80000         Automatic             2
# 8348    Diesel              20000            Manual             2
# 8364    Diesel              60000            Manual             1
#
#      Manufactured_By         Car_Model  Car_Produced_Year  Car_Price  \
# 79            Maruti       Maruti Ritz               2014   420000.0
# 114          Hyundai     Hyundai Venue               2019  1250000.0
# 124          Hyundai       Hyundai i10               2009   249000.0
# 183           Maruti    Maruti Celerio               2015   400000.0
# 197             Fiat        Fiat Linea               2009   375000.0
# ...              ...               ...                ...        ...
# 8279           Honda       Honda Civic               2008   250000.0
# 8325          Maruti        Maruti 800               2004  7000000.0
# 8336             BMW            BMW X1               2011   950000.0
# 8348        Mahindra  Mahindra Scorpio               2012   400000.0
# 8364        Mahindra   Mahindra XUV500               2013   700000.0
#
#       Registration_Year  No_of_Seats  Engine_CC  Mileage(kmpl)   Location  \
# 79                 2014            5       1197          18.50   Banglore
# 114                2019            5        998          18.15   Banglore
# 124                2009            5       1197          20.36   Banglore
# 183                2015            5        998          23.10   Banglore
# 197                2009            5       1368          16.00   Banglore
# ...                 ...          ...        ...            ...        ...
# 8279               2008            5       1799          13.50  Hyderabad
# 8325               2004            4        796          16.10  Hyderabad
# 8336               2011            5       1995          17.05  Hyderabad
# 8348               2012            7       2179          12.05  Hyderabad
# 8364               2013            7       2179          15.10  Hyderabad
#
#       Car_Age
# 79         11
# 114         6
# 124        16
# 183        10
# 197        16
# ...       ...
# 8279       17
# 8325       21
# 8336       14
# 8348       13
# 8364       12
#
# [124 rows x 14 columns]

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (8215, 14)

# %%
data.drop_duplicates(inplace = True)

# %%
for col in data.select_dtypes(exclude='object'):
    plt.figure(figsize=(8,4))
    plt.hist(data[col], bins=30, color="skyblue", edgecolor="black")
    plt.title(f"{col}")
    plt.xlabel(col)           # X-axis = column name
    plt.ylabel("Frequency")   # Y-axis always frequency
    plt.show()

# %%
price = data[(data['Car_Produced_Year']<2009)&(data['Car_Price']>1000000)&(data['Manufactured_By']!= 'BMW')]
data.drop(price.index, inplace = True)

# %%
data.to_csv('Cleaned_Car_Dheko.csv', index = False)

# %%
for i in data.columns:
    if data[i].dtype != 'object':
        sns.histplot(data[i], bins=30, kde=False, color="b")
        plt.show()

# %%
def inv_trans(x):
    if x!=0:
        return 1/x
    else:
        return 0

# data = data_3.copy()
data['Kilometers_Driven'] = data['Kilometers_Driven'].apply(inv_trans)

# %%
plt.figure(figsize=(8,4))
sns.violinplot(data=data['Kilometers_Driven'], color="lightgreen")
plt.xlabel("Kilometers Driven")
plt.title("Violin Plot of Kilometers Driven")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.violinplot(data=data['Kilometers_Driven'], color="lightgreen")
plt.xlabel("Kilometers Driven")
plt.title("Violin Plot of Kilometers Driven")
plt.show()

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
for i in data.columns:
    if data[i].dtype == 'object':   # only true categoricals now
        col_name = i
        data[i] = enc.fit_transform(data[[i]])
        encode = data[i].sort_values().unique()
        globals()[col_name] = {}
        decoded_data = enc.inverse_transform(data[[i]])
        decoded = sorted(np.unique(decoded_data))
        globals()[i] = dict(zip(decoded, encode))

# %%
Location
# Out:
# {'Banglore': np.float64(0.0),
#  'Chennai': np.float64(1.0),
#  'Delhi': np.float64(2.0),
#  'Hyderabad': np.float64(3.0),
#  'Jaipur': np.float64(4.0),
#  'Kolkata': np.float64(5.0)}

# %%
data.to_csv('Preprocessed_Car_Dheko.csv', index = False)

# %%
df = pd.read_csv('Preprocessed_Car_Dheko.csv')

# %%
continuous = df[['Kilometers_Driven','No_of_Owners','Car_Produced_Year','Car_Price','Registration_Year','No_of_Seats','Engine_CC','Mileage(kmpl)','Car_Age']]
categorical = df[['Fuel_Type','Transmission_Type','Manufactured_By','Car_Model','Location']]

# %%
plt.figure(figsize=(16,8))
sns.heatmap(continuous.corr(),annot=True,cmap="Spectral",fmt=".3f")
# Out:
# <Axes: >

# %%
df.drop(df[['Registration_Year','Car_Age']], axis = 1, inplace = True)

# %%
# checking hypothesis testing categorical column to categorical column
from scipy.stats import chi2_contingency

for i in categorical:
    for j in categorical:
        contingency_table = pd.crosstab(df[i], df[j])
        chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)
        print(i,j,p_value)
# Out:
# Fuel_Type Fuel_Type 0.0
# Fuel_Type Transmission_Type 9.931466105274275e-24
# Fuel_Type Manufactured_By 0.0
# Fuel_Type Car_Model 0.0
# Fuel_Type Location 4.620896106652552e-36
# Transmission_Type Fuel_Type 9.931466105274345e-24
# Transmission_Type Transmission_Type 0.0
# Transmission_Type Manufactured_By 0.0
# Transmission_Type Car_Model 0.0
# Transmission_Type Location 7.297526503780326e-33
# Manufactured_By Fuel_Type 0.0
# Manufactured_By Transmission_Type 0.0
# Manufactured_By Manufactured_By 0.0
# Manufactured_By Car_Model 0.0
# Manufactured_By Location 7.677307698217124e-36
# Car_Model Fuel_Type 0.0
# Car_Model Transmission_Type 0.0
# Car_Model Manufactured_By 0.0
# Car_Model Car_Model 0.0
# Car_Model Location 3.874836756187625e-49
# Location Fuel_Type 4.620896106652552e-36
# Location Transmission_Type 7.297526503780431e-33
# Location Manufactured_By 7.677307698216902e-36
# Location Car_Model 3.874836756187625e-49
# Location Location 0.0

# %%
# ==============================
# Car Price Prediction Pipeline
# ==============================

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

# Models
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, GradientBoostingRegressor

# ==============================
# 1. Feature Selection
# ==============================
features = df.drop('Car_Price', axis=1)
target = df['Car_Price']

# Random Forest for feature importance
rf_temp = RandomForestRegressor(n_estimators=20, random_state=40)
rf_temp.fit(features, target)

feature_importance = pd.DataFrame({
    "Feature": features.columns,
    "Score": rf_temp.feature_importances_ * 100
}).sort_values('Score', ascending=False)

print("Feature Importance:\n", feature_importance)

# Drop less important features (example based on your selection)
X = df.drop(['Car_Price','No_of_Seats', 'No_of_Owners'], axis=1)
y = df['Car_Price']

# ==============================
# 2. Train-Test Split
# ==============================
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

print(f"Train shape: {x_train.shape}, Test shape: {x_test.shape}")

# ==============================
# 3. Helper function for evaluation
# ==============================
def evaluate_model(name, model, x_train, y_train, x_test, y_test):
    """Train model and return performance metrics."""
    model.fit(x_train, y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)

    results = {
        "Model": name,
        "Train_MAE": mean_absolute_error(y_train, y_pred_train),
        "Test_MAE": mean_absolute_error(y_test, y_pred_test),
        "Train_R2": r2_score(y_train, y_pred_train),
        "Test_R2": r2_score(y_test, y_pred_test)
    }
    return results

# ==============================
# 4. Train Different Models
# ==============================
models = [
    ("Decision Tree", DecisionTreeRegressor(criterion='squared_error',
                                            max_depth=400, min_samples_split=10,
                                            min_samples_leaf=7, random_state=50)),

    ("KNN", KNeighborsRegressor(n_neighbors=4)),

    ("AdaBoost", AdaBoostRegressor(n_estimators=1000, learning_rate=0.001, random_state=50)),

    ("Random Forest", RandomForestRegressor(criterion='squared_error', n_estimators=700,
                                            max_depth=25, min_samples_split=7,
                                            min_samples_leaf=5, random_state=50)),

    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=400, max_depth=10,
                                                    min_samples_split=7, learning_rate=0.01,
                                                    random_state=50))
]

results = []
for name, model in models:
    results.append(evaluate_model(name, model, x_train, y_train, x_test, y_test))

# ==============================
# 5. Results Comparison
# ==============================
results_df = pd.DataFrame(results)
print("\nModel Performance Comparison:\n")
print(results_df)
# Out:
# Feature Importance:
#                Feature      Score
# 8           Engine_CC  45.379773
# 6   Car_Produced_Year  19.270746
# 2   Transmission_Type   8.679034
# 1   Kilometers_Driven   7.214796
# 5           Car_Model   5.680824
# 9       Mileage(kmpl)   5.525445
# 10           Location   2.960437
# 4     Manufactured_By   1.950247
# 3        No_of_Owners   1.281173
# 7         No_of_Seats   1.197158
# 0           Fuel_Type   0.860365
# Train shape: (6508, 9), Test shape: (1627, 9)
#
# Model Performance Comparison:
#
#                Model      Train_MAE       Test_MAE  Train_R2   Test_R2
# 0      Decision Tree  167941.778146  238744.201174  0.803337  0.627837
# 1                KNN  144689.728027  206900.583897  0.824201  0.664011
# 2           AdaBoost  370295.313059  391061.332071  0.562155  0.519603
# 3      Random Forest  149929.428352  216363.564676  0.826743  0.673247
# 4  Gradient Boosting   72842.021573  197939.153556  0.968055  0.705717

# %% [markdown]
# ### *How to decide the “best” model:*
#
# Lower Test_MAE → better predictive accuracy (smaller errors).
#
# Higher Test_R² → better fit on unseen data.
#
# Close Train vs Test performance → less overfitting.
#
# ### *Analysis:*
#
# Gradient Boosting
# Best Test_R² = 0.682 (highest among all).
#
# Lowest Test_MAE = 182,810.
#
# Training R² is very high (0.975) → some risk of overfitting, but generalizes well.
#
# KNN
#
# Second-best Test_R² = 0.671.
#
# Test_MAE = 192,628 (slightly higher than GB).
#
# Train/Test gap is small → more stable than GB.
#
# Random Forest is close to KNN, but slightly weaker in both MAE and R².

# %%
# checking hypothesis testing categorical column to categorical column
from scipy.stats import chi2_contingency

for i in categorical:
    for j in categorical:
        contingency_table = pd.crosstab(df[i], df[j])
        chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)
        print(i,j,p_value)
# Out:
# Fuel_Type Fuel_Type 0.0
# Fuel_Type Transmission_Type 9.931466105274275e-24
# Fuel_Type Manufactured_By 0.0
# Fuel_Type Car_Model 0.0
# Fuel_Type Location 4.620896106652552e-36
# Transmission_Type Fuel_Type 9.931466105274345e-24
# Transmission_Type Transmission_Type 0.0
# Transmission_Type Manufactured_By 0.0
# Transmission_Type Car_Model 0.0
# Transmission_Type Location 7.297526503780326e-33
# Manufactured_By Fuel_Type 0.0
# Manufactured_By Transmission_Type 0.0
# Manufactured_By Manufactured_By 0.0
# Manufactured_By Car_Model 0.0
# Manufactured_By Location 7.677307698217124e-36
# Car_Model Fuel_Type 0.0
# Car_Model Transmission_Type 0.0
# Car_Model Manufactured_By 0.0
# Car_Model Car_Model 0.0
# Car_Model Location 3.874836756187625e-49
# Location Fuel_Type 4.620896106652552e-36
# Location Transmission_Type 7.297526503780431e-33
# Location Manufactured_By 7.677307698216902e-36
# Location Car_Model 3.874836756187625e-49
# Location Location 0.0

# %%
from sklearn.ensemble import RandomForestRegressor
features = df.drop('Car_Price',axis = 1)
target = df['Car_Price']
model = RandomForestRegressor(n_estimators=20,random_state=40)
model.fit(features,target)
model.feature_importances_
feature_importance = pd.DataFrame({
    "column": features.columns,
    "Score": model.feature_importances_ *100
}).sort_values('Score',ascending=False)#.head(12).column.values
feature_importance
x = df.drop(['Car_Price','Manufactured_By','No_of_Seats','Fuel_Type','No_of_Owners'],axis = 1)
y = df['Car_Price']
print(x.shape)
x
# Out:
# (8135, 7)
#       Kilometers_Driven  Transmission_Type  Car_Model  Car_Produced_Year  \
# 0              0.000008                1.0      154.0               2015
# 1              0.000031                1.0       49.0               2018
# 2              0.000084                1.0      259.0               2018
# 3              0.000056                1.0       85.0               2014
# 4              0.000017                1.0      172.0               2015
# ...                 ...                ...        ...                ...
# 8130           0.000017                1.0      142.0               2013
# 8131           0.000020                0.0       97.0               2014
# 8132           0.000008                0.0       17.0               2018
# 8133           0.000020                0.0      254.0               2019
# 8134           0.000010                1.0      274.0               2015
#
#       Engine_CC  Mileage(kmpl)  Location
# 0           998          23.10       0.0
# 1          1497          17.00       0.0
# 2          1199          23.84       0.0
# 3          1197          19.10       0.0
# 4          1248          23.65       0.0
# ...         ...            ...       ...
# 8130       2179          15.10       3.0
# 8131       2993          14.74       3.0
# 8132       1995          20.37       3.0
# 8133       1497          21.50       3.0
# 8134       2494          12.99       3.0
#
# [8135 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 50)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
from sklearn.tree import DecisionTreeRegressor
model_DT = DecisionTreeRegressor(criterion = 'squared_error', max_depth = 400, min_samples_split = 10, min_samples_leaf = 7, random_state=50)
model_DT.fit(x_train,y_train)
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score

y_pred_test = model_DT.predict(x_test)
y_pred_train = model_DT.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 167377.75164721234
# 243768.15073371623
# 0.8043084727142995
# 0.6211464936810751

# %%
from sklearn.neighbors import KNeighborsRegressor
model_kn = KNeighborsRegressor(n_neighbors = 4)
model_kn.fit(x_train,y_train)
y_pred_test = model_kn.predict(x_test)
y_pred_train = model_kn.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 144723.1868469576
# 208404.88629379225
# 0.8255079405353931
# 0.659916046923261

# %%
from sklearn.ensemble import AdaBoostRegressor
model_ada = AdaBoostRegressor(n_estimators=1000, learning_rate=0.001)
model_ada.fit(x_train,y_train)
y_pred_test = model_ada.predict(x_test)
y_pred_train = model_ada.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 369867.71917797613
# 390724.010941948
# 0.5620666686580713
# 0.5188998213124077

# %%
from sklearn.ensemble import RandomForestRegressor
model_RF = RandomForestRegressor(criterion = 'squared_error',n_estimators=700 ,max_depth = 25, min_samples_split = 7, min_samples_leaf = 5, random_state=50)
model_RF.fit(x_train,y_train)
y_pred_test = model_RF.predict(x_test)
y_pred_train = model_RF.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 150362.53567279142
# 217368.92444625593
# 0.825851291089769
# 0.6747102739445396

# %%
from sklearn.ensemble import GradientBoostingRegressor
model_GB = GradientBoostingRegressor(n_estimators=400, max_depth=10, min_samples_split=7, learning_rate=0.01)
model_GB.fit(x_train,y_train)
y_pred_test = model_GB.predict(x_test)
y_pred_train = model_GB.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 75151.20616198584
# 193555.31499480113
# 0.966946327052979
# 0.7107488334315424

# %%
import pickle

with open('GradientBoost_model_new1.pkl', 'wb') as file:
    pickle.dump(model_GB,file)
